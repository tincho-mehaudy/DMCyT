# %% [markdown]
# <a href="https://colab.research.google.com/github/tincho-mehaudy/DMCyT/blob/master/Consigna%201%20(solo%20datos).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Consigna 1:
#
# Utilizando la API de Spotify se descargó la información de 4092 pistas de audio. Cada registro tiene variables de features de alto (*audio_features*), bajo nivel (*audio_analysis*) y metadata de los tracks. La idea es limpiar los campos a utilizar y hacer un primer análisis de los datos.
#
# Para facilitar los primeros pasos utilizar una pequeña porción aleatoria de los datos e ir aumentando progresivamente. Observación: los datos de *audio_analysis* pesan 1.3 GB
#
# # Dataset *tracks*
#
# -   De los datos de *tracks*, separar las etiquetas que se podrán utilizar para la validación externa (Artista, Álbum, Año, Género), de los campos que no se utilizarán.
#
# # Dataset *audio_features*
#
# El dataset *audio_features* contiene 9 atributos globales de alto nivel para cada pista de audio.
#
# -   Con los datos de *audio_features*, generar un gráfico tipo *scatter matrix*.
#
# -   Identificar variables más o menos informativas *a priori* y variables que requieran, además de la estandarización, alguna corrección para asimilar la distribución a una normal.
#
# -   Estandarizar y volver a generar un gráfico tipo *scatter matrix*.
#
# -   Identificar, si es que hay, valores extremos que sea necesario descartar.
#
# # Dataset *audio_analysis*
#
# El dataset *audio_analysis* contiene las variables continuas de bajo nivel, estimadas en ventanas temporales, como *timbre* o *pitches*. Como primer paso, deberán:
#
# -   Resumir estas variables en valores por canción. Por ejemplo, tomar el promedio o el desvío estándar del timbre entre todas las ventanas, obteniendo 12 valores de timbre promedio y 12 valores de desvío estándar del timbre por canción.
#
# -   Contruir un *data frame* con estos valores.
#
# -   Generar un gráfico tipo *scatter matrix*.
#
# -   Identificar variables más o menos informativas *a priori* y variables que requieran, además de la estandarización, alguna corrección para asimilar la distribución a una normal.
#
# -   Estandarizar y volver a generar un gráfico tipo *scatter matrix*.
#
# -   Identificar, si es que hay, valores extremos que sea necesario descartar.

# %% [markdown]
# ## Bajamos los datos

# %%
# !wget https://www.dropbox.com/s/ms6260jqmsmz5qu/audio_features.pickle?dl=1 -O audio_features.pickle
# !wget https://www.dropbox.com/s/8d0y9bms80ly8ui/tracks.pickle?dl=1 -O tracks.pickle
# !wget https://www.dropbox.com/s/1cmb8e8zvv6hsfs/audio_analysis.pickle?dl=1 -O audio_analysis.pickle
# Out:
# --2020-09-18 23:22:43--  https://www.dropbox.com/s/ms6260jqmsmz5qu/audio_features.pickle?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.1, 2620:100:6021:1::a27d:4101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/ms6260jqmsmz5qu/audio_features.pickle [following]
# --2020-09-18 23:22:43--  https://www.dropbox.com/s/dl/ms6260jqmsmz5qu/audio_features.pickle
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucd19a09d6a79a3455a90bff57e2.dl.dropboxusercontent.com/cd/0/get/A_q85vKa3ldQKw9UAmvCex7iyHNEs4FXfJoxtoN8l_FIQIG7sOQNi_niWl0804bRgbAtJw4UChc9Le3ZIFzSJmkASp7jk_4BlPhRE_KcecdWJNkJGvNEalVsJRUgBrIRmQY/file?dl=1# [following]
# --2020-09-18 23:22:44--  https://ucd19a09d6a79a3455a90bff57e2.dl.dropboxusercontent.com/cd/0/get/A_q85vKa3ldQKw9UAmvCex7iyHNEs4FXfJoxtoN8l_FIQIG7sOQNi_niWl0804bRgbAtJw4UChc9Le3ZIFzSJmkASp7jk_4BlPhRE_KcecdWJNkJGvNEalVsJRUgBrIRmQY/file?dl=1
# Resolving ucd19a09d6a79a3455a90bff57e2.dl.dropboxusercontent.com (ucd19a09d6a79a3455a90bff57e2.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6021:15::a27d:410f
# Connecting to ucd19a09d6a79a3455a90bff57e2.dl.dropboxusercontent.com (ucd19a09d6a79a3455a90bff57e2.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1329480 (1.3M) [application/binary]
# Saving to: ‘audio_features.pickle’
#
# audio_features.pick 100%[===================>]   1.27M  2.32MB/s    in 0.5s
#
# 2020-09-18 23:22:47 (2.32 MB/s) - ‘audio_features.pickle’ saved [1329480/1329480]
#
# --2020-09-18 23:22:47--  https://www.dropbox.com/s/8d0y9bms80ly8ui/tracks.pickle?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.1, 2620:100:6021:1::a27d:4101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/8d0y9bms80ly8ui/tracks.pickle [following]
# --2020-09-18 23:22:48--  https://www.dropbox.com/s/dl/8d0y9bms80ly8ui/tracks.pickle
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc18be06d1c0f4f130ffd83776c8.dl.dropboxusercontent.com/cd/0/get/A_qzF0eG9J77BTguHUm6HV11H2YBeb3OgIaWbe8Plb4KscI3dB_qn5GFovRyNy9mUh2gkAB0_KG0s2DYsI_45mYdaZrWR11wLD9NksTkQuXCsB5Y7NFgnGpnFyPmkxsWV2E/file?dl=1# [following]
# --2020-09-18 23:22:48--  https://uc18be06d1c0f4f130ffd83776c8.dl.dropboxusercontent.com/cd/0/get/A_qzF0eG9J77BTguHUm6HV11H2YBeb3OgIaWbe8Plb4KscI3dB_qn5GFovRyNy9mUh2gkAB0_KG0s2DYsI_45mYdaZrWR11wLD9NksTkQuXCsB5Y7NFgnGpnFyPmkxsWV2E/file?dl=1
# Resolving uc18be06d1c0f4f130ffd83776c8.dl.dropboxusercontent.com (uc18be06d1c0f4f130ffd83776c8.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6021:15::a27d:410f
# Connecting to uc18be06d1c0f4f130ffd83776c8.dl.dropboxusercontent.com (uc18be06d1c0f4f130ffd83776c8.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8151675 (7.8M) [application/binary]
# Saving to: ‘tracks.pickle’
#
# tracks.pickle       100%[===================>]   7.77M  7.58MB/s    in 1.0s
#
# 2020-09-18 23:22:50 (7.58 MB/s) - ‘tracks.pickle’ saved [8151675/8151675]
#
# --2020-09-18 23:22:50--  https://www.dropbox.com/s/1cmb8e8zvv6hsfs/audio_analysis.pickle?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.1, 2620:100:6021:1::a27d:4101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/1cmb8e8zvv6hsfs/audio_analysis.pickle [following]
# --2020-09-18 23:22:50--  https://www.dropbox.com/s/dl/1cmb8e8zvv6hsfs/audio_analysis.pickle
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc7b6999f8083472ec257ee99526.dl.dropboxusercontent.com/cd/0/get/A_oXMOQ_lO9785gg-DtN0f6OgQxWHBs-l5chx4sRL5zxgTBu_K1F6vC7H2TKbCk6K33gop2045fzg2NCg8K_ldbkXYBPewC6FENl2RRk1-OQWZg6jF18804YAKcEkNkSHeQ/file?dl=1# [following]
# --2020-09-18 23:22:51--  https://uc7b6999f8083472ec257ee99526.dl.dropboxusercontent.com/cd/0/get/A_oXMOQ_lO9785gg-DtN0f6OgQxWHBs-l5chx4sRL5zxgTBu_K1F6vC7H2TKbCk6K33gop2045fzg2NCg8K_ldbkXYBPewC6FENl2RRk1-OQWZg6jF18804YAKcEkNkSHeQ/file?dl=1
# Resolving uc7b6999f8083472ec257ee99526.dl.dropboxusercontent.com (uc7b6999f8083472ec257ee99526.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6021:15::a27d:410f
# Connecting to uc7b6999f8083472ec257ee99526.dl.dropboxusercontent.com (uc7b6999f8083472ec257ee99526.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1320027792 (1.2G) [application/binary]
# Saving to: ‘audio_analysis.pickle’
#
# audio_analysis.pick 100%[===================>]   1.23G  17.0MB/s    in 77s
#
# 2020-09-18 23:24:08 (16.4 MB/s) - ‘audio_analysis.pickle’ saved [1320027792/1320027792]

# %%
df_af = pd.read_pickle('audio_features.pickle')
df_tracks = pd.read_pickle('tracks.pickle')
df_aa = pd.read_pickle('audio_analysis.pickle')

# %%
df_tracks['genre'].value_counts().plot.bar(figsize=(6,4));
plt.title('Géneros')
plt.show()
df_tracks['artists'].value_counts()[:26].plot.bar(figsize=(18,4));
plt.title('Artistas');

# %% [markdown]
# Dataset tracks De los datos de tracks, separar las etiquetas que se podrán utilizar para la validación externa (Artista, Álbum, Año, Género), de los campos que no se utilizarán.

# %%
df_tracks.head()

# %%
df_tracks.columns

# %%
df2 = df_tracks.loc[:,['artists','album','genre']]
df2.head()

# %%
album=df2['album'].apply(pd.Series)
album.head()

# %%
df_af.shape

# %%
df_tracks.shape

# %%
df_aa.shape

# %%
album.shape
